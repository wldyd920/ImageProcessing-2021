# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img1 = cv2.imread('lena.png',0)
img2 = cv2.imread('fingerprint1.jpg')

# %%
img1.shape
# Out:
# (512, 512)

# %%
img2.shape
# Out:
# (225, 225, 3)

# %%
img3 = cv2.pyrDown(img1)
img3.shape
# Out:
# (256, 256)

# %%
# plt.figure(figsize=(12,10))
plt.subplot(121),plt.imshow(img1,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img3,cmap = 'gray')
plt.title('Gaussian Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img41 = cv2.pyrDown(img1)
img42 = cv2.pyrDown(img41)
img43 = cv2.pyrDown(img42)
img44 = cv2.pyrDown(img43)

# %%
plt.subplot(121),plt.imshow(img1,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img44,cmap = 'gray')
plt.title('PyrDown Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img1 = cv2.imread('lena.png',0)

img41 = cv2.pyrDown(img1)
img42 = cv2.pyrDown(img41)
img43 = cv2.pyrDown(img42)
img44 = cv2.pyrDown(img43)

img51 = cv2.pyrUp(img44)
img52 = cv2.pyrUp(img51)
img53 = cv2.pyrUp(img52)
img54 = cv2.pyrUp(img53)

# %%
plt.subplot(121),plt.imshow(img1,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img54,cmap = 'gray')
plt.title('PyrDown-Up Image'), plt.xticks([]), plt.yticks([])
plt.show()
