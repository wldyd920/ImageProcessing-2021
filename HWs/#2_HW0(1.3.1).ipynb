# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('messi2.jpg')

# %%
# accessing pixel and color value

# %%
# raw image
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

#  accessing (y,x) = (100,100)
px = img[100,100]
print (px)

# accessing only red pixel
red = img[100,100,2]
print(red)

# modify pixel value
img[100, 100] = [255,255,255]
print (img[100,100])

# difference
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# [ 20  64 195]
# 195
# [255 255 255]

# %%
# accessing RED value
img.item(10,10,2)
# Out:
# 182

# %%
# modifying RED value
img.itemset((10,10,2),250)
img.item(10,10,2)
# Out:
# 250

# %%
# accessing properties

# %%
# check shape
print (img.shape)
# Out:
# (332, 332, 3)

# %%
# check size
print (img.size)
# Out:
# 330672

# %%
# check dtype
print(img.dtype)
# Out:
# uint8

# %%
# check image now
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# ROI

# %%
center = img[150:200, 120:200]
img[100:150, 120:200] = center

# %%
# check image
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# split
img_b, img_g, img_r = cv2.split(img)
print(img.shape)

# check image
plt.imshow(cv2.cvtColor(img_b, cv2.COLOR_BGR2RGB))
plt.show()
plt.imshow(cv2.cvtColor(img_g, cv2.COLOR_BGR2RGB))
plt.show()
plt.imshow(cv2.cvtColor(img_r, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# (332, 332, 3)

# %%
# merge
img = cv2.merge([img_r, img_g, img_b])

# easier to check image
plt.imshow(img)
plt.show()

# %%
BLUE = [255,0,0]

img1 = img

replicate = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_WRAP)
constant= cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_CONSTANT,value=BLUE)

plt.figure(figsize=(10,8))

plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')

plt.show()
